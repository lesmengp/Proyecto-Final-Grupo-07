# %% [markdown]
# <a href="https://colab.research.google.com/github/lesmengp/Proyecto-Final-Grupo-07/blob/Rama-JACH/yelp_user.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google.cloud

# %%
pip install gcsfs

# %%
pip install google-cloud-storage

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import pandas as pd
import gcsfs

# Definir la ruta al archivo en Google Cloud Storage
project_name = 'Proyecto Final - Henry'  # Reemplaza 'your-project-name' con el nombre de tu proyecto
bucket_name = 'gmy'
folder_name = 'Yelp'
file_name = 'user.parquet'
gcs_path = f'gs://{bucket_name}/{folder_name}/{file_name}'

# Cargar el archivo Parquet en un DataFrame
with gcsfs.GCSFileSystem(project=project_name).open(gcs_path, 'rb') as f:
    df_user = pd.read_parquet(f)

# Ahora "df_user" contiene los datos del archivo Parquet en forma de DataFrame

# %%
df_user
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...
